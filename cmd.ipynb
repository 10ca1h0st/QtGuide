# %%
import json
name='飞机.json'
f = open(name,encoding='utf-8')
content = f.read()
content = json.loads(content)

# %%
content
# Out:
# {'data': [{'型号': '型号1',
#    '飞行距离': '1000km',
#    '飞行高度': '1000km',
#    '飞行时间': '1hour',
#    '载人数': '2',
#    '制造国家': 'cn',
#    '价格': '$100000000',
#    '使用年限': '5',
#    '飞行最大速度': '500km/h',
#    '承载最大数量': '100kg'},
#   {'型号': '型号2',
#    '飞行距离': '2000km',
#    '飞行高度': '3000km',
#    '飞行时间': '1hour',
#    '载人数': '2',
#    '制造国家': 'cn',
#    '价格': '$100300000',
#    '使用年限': '5',
#    '飞行最大速度': '520km/h',
#    '承载最大数量': '100kg'},
#   {'型号': '型号3',
#    '飞行距离': '3000km',
#    '飞行高度': '1000km',
#    '飞行时间': '1hour',
#    '载人数': '2',
#    '制造国家': 'cn',
#    '价格': '$10003000',
#    '使用年限': '5',
#    '飞行最大速度': '500km/h',
#    '承载最大数量': '100kg'},
#   {'型号': '型号4',
#    '飞行距离': '4000km',
#    '飞行高度': '1000km',
#    '飞行时间': '1hour',
#    '载人数': '2',
#    '制造国家': 'cn',
#    '价格': '$100000400',
#    '使用年限': '5',
#    '飞行最大速度': '500km/h',
#    '承载最大数量': '100kg'}]}

# %%
content=content['data']

# %%
content
# Out:
# [{'型号': '型号1',
#   '飞行距离': '1000km',
#   '飞行高度': '1000km',
#   '飞行时间': '1hour',
#   '载人数': '2',
#   '制造国家': 'cn',
#   '价格': '$100000000',
#   '使用年限': '5',
#   '飞行最大速度': '500km/h',
#   '承载最大数量': '100kg'},
#  {'型号': '型号2',
#   '飞行距离': '2000km',
#   '飞行高度': '3000km',
#   '飞行时间': '1hour',
#   '载人数': '2',
#   '制造国家': 'cn',
#   '价格': '$100300000',
#   '使用年限': '5',
#   '飞行最大速度': '520km/h',
#   '承载最大数量': '100kg'},
#  {'型号': '型号3',
#   '飞行距离': '3000km',
#   '飞行高度': '1000km',
#   '飞行时间': '1hour',
#   '载人数': '2',
#   '制造国家': 'cn',
#   '价格': '$10003000',
#   '使用年限': '5',
#   '飞行最大速度': '500km/h',
#   '承载最大数量': '100kg'},
#  {'型号': '型号4',
#   '飞行距离': '4000km',
#   '飞行高度': '1000km',
#   '飞行时间': '1hour',
#   '载人数': '2',
#   '制造国家': 'cn',
#   '价格': '$100000400',
#   '使用年限': '5',
#   '飞行最大速度': '500km/h',
#   '承载最大数量': '100kg'}]

# %%
len(content[0].keys())
# Out:
# 10

# %%
content[0]
# Out:
# {'型号': '型号1',
#  '飞行距离': '1000km',
#  '飞行高度': '1000km',
#  '飞行时间': '1hour',
#  '载人数': '2',
#  '制造国家': 'cn',
#  '价格': '$100000000',
#  '使用年限': '5',
#  '飞行最大速度': '500km/h',
#  '承载最大数量': '100kg'}

# %%
content[0].values()
# Out:
# dict_values(['型号1', '1000km', '1000km', '1hour', '2', 'cn', '$100000000', '5', '500km/h', '100kg'])

# %%
for i,j in enumerate(content[0].values()):
    print(i)
    print(j)
# Out:
# 0
# 型号1
# 1
# 1000km
# 2
# 1000km
# 3
# 1hour
# 4
# 2
# 5
# cn
# 6
# $100000000
# 7
# 5
# 8
# 500km/h
# 9
# 100kg
